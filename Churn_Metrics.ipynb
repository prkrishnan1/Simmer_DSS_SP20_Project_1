# %% [markdown]
# # Churn Metrics
#
# Adding metrics to people dataset for modeling

# %%
import numpy as np
import pandas as pd
import re
import matplotlib
import seaborn as sns

# %% [markdown]
# Read the events and people data into dataframes

# %%
events = pd.read_csv('Cleaned_Dataset_With_ID.csv', low_memory=False)
people = pd.read_csv('cleaned_people.csv', low_memory= False)

# %% [markdown]
# # Adding Number of Ratings Metric

# %%
def ratings(events_df, people_df):
    #creating dictionary with distinct id and number of ratings
    number_ratings_dict = events_df[events_df['name_x'] == 'Rating Flow - Complete'].groupby('distinct_id').count()['name_x'].to_dict()
    
    #creating df with just distinct_id and mapping ratings to each distinct id, filling in Nans with 0
    short_df = people_df[['distinct_id']]
    short_df['number_ratings'] = short_df['distinct_id'].map(number_ratings_dict)
    short_df = short_df.fillna(0)
    
    # drop 'distinct_id' column from short_df and then append to the original dataframe
    short_df = short_df.drop(columns = ['distinct_id'])
    people_df = pd.concat([people_df, short_df], axis=1)
    
    return people_df

# %%
ratings(events, people)
# Out:
# C:\Users\annaw\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#      Unnamed: 0                           distinct_id  \
# 0             0                       hr@gmail.com_87
# 1             1  E2D9AB63-1718-4D1E-936F-10BE1D889989
# 2             2            vaibhavverma9@gmail.com_56
# 3             3  0C954A3F-0AB6-4D12-B4E9-D916C95B0C6E
# 4             4               addidas23@gmail.com_139
# ..          ...                                   ...
# 176         176  52774481-EECA-4703-8F31-F634B24773BE
# 177         177  F4B6EE31-E835-4C5D-8387-456DFF4E9A3D
# 178         178  04ADA4C3-9212-49DA-B600-67A8403D69C3
# 179         179  619EECB8-EA49-493B-9048-4EAB912BF98E
# 180         180  1D828D20-752E-45B9-966A-C893DF041CFE
#
#      ae_total_app_session_length            name country_code auth_provider  \
# 0                         345721   Harshil Raval           IN        Foodie
# 1                           4412     Theodore Wu           US        Google
# 2                          71430   Vaibhav Verma           IN        Foodie
# 3                          12836      Tiffany Qi           US      Facebook
# 4                           2066   Nathan Nangia           US        Foodie
# ..                           ...             ...          ...           ...
# 176                       161801     Reyna Huang           US      Facebook
# 177                         8308  Christine Duke           US       Unknown
# 178                         2283   Alexandria Ma           US       Unknown
# 179                         4227         Lucy Li           US      Facebook
# 180                         6065     Kecheng Liu           US        Google
#
#      ae_total_app_sessions             timezone                  last_seen  \
# 0                     1759         Asia/Kolkata  2020-03-03 06:08:32+00:00
# 1                       59  America/Los_Angeles  2019-09-08 03:15:47+00:00
# 2                      621         Asia/Kolkata  2019-04-15 15:18:25+00:00
# 3                       77  America/Los_Angeles  2019-11-09 18:33:06+00:00
# 4                       39      America/Chicago  2020-03-18 15:09:21+00:00
# ..                     ...                  ...                        ...
# 176                   1168     America/New_York  2020-02-23 00:59:33+00:00
# 177                     53      America/Chicago  2020-03-21 16:43:15+00:00
# 178                     45      America/Chicago  2020-01-19 01:41:22+00:00
# 179                     67      America/Chicago  2019-12-12 03:35:49+00:00
# 180                     85      America/Chicago  2020-02-25 00:36:12+00:00
#
#     ios_app_version ios_version ios_device_model ios_lib_version  \
# 0             2.5.0      13.2.3        iPhone9,3           3.4.9
# 1             2.0.5        13.1        iPhone9,1           3.4.4
# 2             1.3.7        12.2        iPhone7,1           3.3.3
# 3             2.1.6      13.1.3        iPhone9,3           3.4.4
# 4             2.5.4        13.4       iPhone11,2           3.4.9
# ..              ...         ...              ...             ...
# 176           2.4.7      13.3.1       iPhone12,1           3.4.4
# 177           2.5.0      13.3.1       iPhone12,3           3.4.9
# 178           2.3.3        13.2       iPhone11,8           3.4.4
# 179           2.3.3        13.2       iPhone12,3           3.4.4
# 180           2.4.7      13.3.1       iPhone11,2           3.4.4
#
#                   ae_first_app_open_date               active_timespan  \
# 0    2019-05-30 01:08:51.984962560+00:00   278 days 04:59:40.015037440
# 1              2019-04-22 20:34:46+00:00   138 days 06:41:01.000000000
# 2    2019-05-30 01:08:51.984962560+00:00  -45 days +14:09:33.015037440
# 3              2019-05-01 06:57:08+00:00   192 days 11:35:58.000000000
# 4    2019-05-30 01:08:51.984962560+00:00   293 days 14:00:29.015037440
# ..                                   ...                           ...
# 176            2019-02-08 14:15:24+00:00   379 days 10:44:09.000000000
# 177            2018-12-03 21:10:02+00:00   473 days 19:33:13.000000000
# 178            2019-06-11 14:14:02+00:00   221 days 11:27:20.000000000
# 179            2019-05-23 13:42:40+00:00   202 days 13:53:09.000000000
# 180            2019-03-09 14:26:38+00:00   352 days 10:09:34.000000000
#
#      average_session_time  number_ratings
# 0              196.544059           130.0
# 1               74.779661             0.0
# 2              115.024155             0.0
# 3              166.701299            10.0
# 4               52.974359             3.0
# ..                    ...             ...
# 176            138.528253             2.0
# 177            156.754717             0.0
# 178             50.733333             0.0
# 179             63.089552             0.0
# 180             71.352941             0.0
#
# [181 rows x 17 columns]
